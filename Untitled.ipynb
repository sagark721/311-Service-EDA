# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set()

# %%
data=pd.read_csv('311_Service_Requests_from_2010_to_Present.csv')
# Out:
# C:\Users\Sagar-PC\.conda\envs\ML\lib\site-packages\IPython\core\interactiveshell.py:3071: DtypeWarning: Columns (48,49) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
pd.set_option('display.max_columns',60)

# %%
data.head()
# Out:
#    Unique Key            Created Date    Closed Date Agency  \
# 0    32310363  12/31/2015 11:59:45 PM  01-01-16 0:55   NYPD
# 1    32309934  12/31/2015 11:59:44 PM  01-01-16 1:26   NYPD
# 2    32309159  12/31/2015 11:59:29 PM  01-01-16 4:51   NYPD
# 3    32305098  12/31/2015 11:57:46 PM  01-01-16 7:43   NYPD
# 4    32306529  12/31/2015 11:56:58 PM  01-01-16 3:24   NYPD
#
#                        Agency Name           Complaint Type  \
# 0  New York City Police Department  Noise - Street/Sidewalk
# 1  New York City Police Department         Blocked Driveway
# 2  New York City Police Department         Blocked Driveway
# 3  New York City Police Department          Illegal Parking
# 4  New York City Police Department          Illegal Parking
#
#                      Descriptor    Location Type  Incident Zip  \
# 0              Loud Music/Party  Street/Sidewalk       10034.0
# 1                     No Access  Street/Sidewalk       11105.0
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300698 entries, 0 to 300697
# Data columns (total 53 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   Unique Key                      300698 non-null  int64
#  1   Created Date                    300698 non-null  object
#  2   Closed Date                     298534 non-null  object
#  3   Agency                          300698 non-null  object
#  4   Agency Name                     300698 non-null  object
#  5   Complaint Type                  300698 non-null  object
#  6   Descriptor                      294784 non-null  object
#  7   Location Type                   300567 non-null  object
#  8   Incident Zip                    298083 non-null  float64
#  9   Incident Address                256288 non-null  object
#  10  Street Name                     256288 non-null  object
#  11  Cross Street 1                  251419 non-null  object
# ...

# %%
data.drop(['Intersection Street 1', 'Intersection Street 2', 'Landmark','School or Citywide Complaint','Vehicle Type','Taxi Company Borough','Taxi Pick Up Location','Bridge Highway Name','Bridge Highway Direction','Road Ramp','Bridge Highway Segment','Garage Lot Name','Ferry Direction','Ferry Terminal Name'],axis=1,inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300698 entries, 0 to 300697
# Data columns (total 39 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   Unique Key                      300698 non-null  int64
#  1   Created Date                    300698 non-null  object
#  2   Closed Date                     298534 non-null  object
#  3   Agency                          300698 non-null  object
#  4   Agency Name                     300698 non-null  object
#  5   Complaint Type                  300698 non-null  object
#  6   Descriptor                      294784 non-null  object
#  7   Location Type                   300567 non-null  object
#  8   Incident Zip                    298083 non-null  float64
#  9   Incident Address                256288 non-null  object
#  10  Street Name                     256288 non-null  object
#  11  Cross Street 1                  251419 non-null  object
# ...

# %%
data.head()
# Out:
#    Unique Key            Created Date    Closed Date Agency  \
# 0    32310363  12/31/2015 11:59:45 PM  01-01-16 0:55   NYPD
# 1    32309934  12/31/2015 11:59:44 PM  01-01-16 1:26   NYPD
# 2    32309159  12/31/2015 11:59:29 PM  01-01-16 4:51   NYPD
# 3    32305098  12/31/2015 11:57:46 PM  01-01-16 7:43   NYPD
# 4    32306529  12/31/2015 11:56:58 PM  01-01-16 3:24   NYPD
#
#                        Agency Name           Complaint Type  \
# 0  New York City Police Department  Noise - Street/Sidewalk
# 1  New York City Police Department         Blocked Driveway
# 2  New York City Police Department         Blocked Driveway
# 3  New York City Police Department          Illegal Parking
# 4  New York City Police Department          Illegal Parking
#
#                      Descriptor    Location Type  Incident Zip  \
# 0              Loud Music/Party  Street/Sidewalk       10034.0
# 1                     No Access  Street/Sidewalk       11105.0
# ...

# %%
data['Address Type'].unique()
# Out:
# array(['ADDRESS', nan, 'INTERSECTION', 'LATLONG', 'BLOCKFACE',
#        'PLACENAME'], dtype=object)

# %%
data['Address Type'].value_counts()
# Out:
# ADDRESS         238644
# INTERSECTION     43366
# BLOCKFACE        12014
# LATLONG           3509
# PLACENAME          350
# Name: Address Type, dtype: int64

# %%
data.drop(['Address Type'],axis=1,inplace=True)

# %%
data['Facility Type'].unique()
# Out:
# array(['Precinct', nan], dtype=object)

# %%
data['Facility Type'].value_counts()
# Out:
# Precinct    298527
# Name: Facility Type, dtype: int64

# %%
data['Facility Type'].isnull().sum()
# Out:
# 2171

# %%
data['Park Facility Name'].unique()
# Out:
# array(['Unspecified', 'Alley Pond Park - Nature Center'], dtype=object)

# %%
data['Park Facility Name'].value_counts()
# Out:
# Unspecified                        300697
# Alley Pond Park - Nature Center         1
# Name: Park Facility Name, dtype: int64

# %%
data.drop(['Park Facility Name'],axis=1,inplace=True)

# %%
data['School Address'].unique()
# Out:
# array(['Unspecified', 'Grand Central Parkway, near the soccer field'],
#       dtype=object)

# %%
data['School Address'].value_counts()
# Out:
# Unspecified                                     300697
# Grand Central Parkway, near the soccer field         1
# Name: School Address, dtype: int64

# %%
data.drop(['School Address'],axis=1,inplace=True)

# %%
data['School City'].unique()
# Out:
# array(['Unspecified', 'QUEENS'], dtype=object)

# %%
data['School City'].value_counts()
# Out:
# Unspecified    300697
# QUEENS              1
# Name: School City, dtype: int64

# %%
data.drop(['School City'],axis=1,inplace=True)

# %%
data['School Code'].unique()
# Out:
# array(['Unspecified', nan], dtype=object)

# %%
del(data['School Code'])

# %%
data['School Not Found'].unique()
# Out:
# array(['N'], dtype=object)

# %%
del(data['School Not Found'])

# %%
data['School Name'].unique()
# Out:
# array(['Unspecified', 'Alley Pond Park - Nature Center'], dtype=object)

# %%
del(data['School Name'])

# %%
data['School Number'].unique()
# Out:
# array(['Unspecified', 'Q001'], dtype=object)

# %%
del(data['School Number'])

# %%
del(data['School Phone Number'])

# %%
data.drop(['School Region','School State', 'School Zip'],axis=1,inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300698 entries, 0 to 300697
# Data columns (total 27 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   Unique Key                      300698 non-null  int64
#  1   Created Date                    300698 non-null  object
#  2   Closed Date                     298534 non-null  object
#  3   Agency                          300698 non-null  object
#  4   Agency Name                     300698 non-null  object
#  5   Complaint Type                  300698 non-null  object
#  6   Descriptor                      294784 non-null  object
#  7   Location Type                   300567 non-null  object
#  8   Incident Zip                    298083 non-null  float64
#  9   Incident Address                256288 non-null  object
#  10  Street Name                     256288 non-null  object
#  11  Cross Street 1                  251419 non-null  object
# ...

# %%
data['Cross Street 1'].unique()
# Out:
# array(['ACADEMY STREET', '27 STREET', 'EAST 198 STREET', ...,
#        '80TH STREET', 'E 186', 'EAST 186'], dtype=object)

# %%
data['Facility Type'].unique()
# Out:
# array(['Precinct', nan], dtype=object)

# %%
data['X Coordinate (State Plane)'].nunique()
# Out:
# 63226

# %%
type(data['Created Date'].iloc[0])
# Out:
# str

# %%
type(data['Closed Date'].iloc[0])
# Out:
# str

# %%
pd.to_datetime(data['Created Date'])
# Out:
# 0        2015-12-31 23:59:45
# 1        2015-12-31 23:59:44
# 2        2015-12-31 23:59:29
# 3        2015-12-31 23:57:46
# 4        2015-12-31 23:56:58
#                  ...
# 300693   2015-03-29 00:33:41
# 300694   2015-03-29 00:33:28
# 300695   2015-03-29 00:33:03
# 300696   2015-03-29 00:33:02
# 300697   2015-03-29 00:33:01
# Name: Created Date, Length: 300698, dtype: datetime64[ns]

# %%
pd.to_datetime(data['Closed Date'])
# Out:
# 0        2016-01-01 00:55:00
# 1        2016-01-01 01:26:00
# 2        2016-01-01 04:51:00
# 3        2016-01-01 07:43:00
# 4        2016-01-01 03:24:00
#                  ...
# 300693                   NaT
# 300694   2015-03-29 02:33:59
# 300695   2015-03-29 03:40:20
# 300696   2015-03-29 04:38:35
# 300697   2015-03-29 04:41:50
# Name: Closed Date, Length: 300698, dtype: datetime64[ns]

# %%
data.head()
# Out:
#    Unique Key            Created Date    Closed Date Agency  \
# 0    32310363  12/31/2015 11:59:45 PM  01-01-16 0:55   NYPD
# 1    32309934  12/31/2015 11:59:44 PM  01-01-16 1:26   NYPD
# 2    32309159  12/31/2015 11:59:29 PM  01-01-16 4:51   NYPD
# 3    32305098  12/31/2015 11:57:46 PM  01-01-16 7:43   NYPD
# 4    32306529  12/31/2015 11:56:58 PM  01-01-16 3:24   NYPD
#
#                        Agency Name           Complaint Type  \
# 0  New York City Police Department  Noise - Street/Sidewalk
# 1  New York City Police Department         Blocked Driveway
# 2  New York City Police Department         Blocked Driveway
# 3  New York City Police Department          Illegal Parking
# 4  New York City Police Department          Illegal Parking
#
#                      Descriptor    Location Type  Incident Zip  \
# 0              Loud Music/Party  Street/Sidewalk       10034.0
# 1                     No Access  Street/Sidewalk       11105.0
# ...

# %%
data['Created Date'].isnull().sum()
# Out:
# 0

# %%
data['Closed Date'].isnull().sum()
# Out:
# 2164

# %%
data['Closed Date'].fillna(0)
# Out:
# 0                  01-01-16 0:55
# 1                  01-01-16 1:26
# 2                  01-01-16 4:51
# 3                  01-01-16 7:43
# 4                  01-01-16 3:24
#                    ...
# 300693                         0
# 300694    03/29/2015 02:33:59 AM
# 300695    03/29/2015 03:40:20 AM
# 300696    03/29/2015 04:38:35 AM
# 300697    03/29/2015 04:41:50 AM
# Name: Closed Date, Length: 300698, dtype: object

# %%
data['Closed Date']= pd.to_datetime(data['Closed Date'])

# %%
data['Created Date']= pd.to_datetime(data['Created Date'])

# %%
data['Request Closing Time ']=data['Closed Date'] - data['Created Date']

# %%
data.head()
# Out:
#    Unique Key        Created Date         Closed Date Agency  \
# 0    32310363 2015-12-31 23:59:45 2016-01-01 00:55:00   NYPD
# 1    32309934 2015-12-31 23:59:44 2016-01-01 01:26:00   NYPD
# 2    32309159 2015-12-31 23:59:29 2016-01-01 04:51:00   NYPD
# 3    32305098 2015-12-31 23:57:46 2016-01-01 07:43:00   NYPD
# 4    32306529 2015-12-31 23:56:58 2016-01-01 03:24:00   NYPD
#
#                        Agency Name           Complaint Type  \
# 0  New York City Police Department  Noise - Street/Sidewalk
# 1  New York City Police Department         Blocked Driveway
# 2  New York City Police Department         Blocked Driveway
# 3  New York City Police Department          Illegal Parking
# 4  New York City Police Department          Illegal Parking
#
#                      Descriptor    Location Type  Incident Zip  \
# 0              Loud Music/Party  Street/Sidewalk       10034.0
# 1                     No Access  Street/Sidewalk       11105.0
# ...

# %%
data['Complaint Type'].nunique()
# Out:
# 24

# %%
data['Ones']=data['Unique Key']/data['Unique Key']

# %%
Complaint_Counts=data.groupby('Complaint Type').sum()['Ones'].reset_index().sort_values(by='Ones',ascending=False).head(10)

# %%
#Complaint_Counts.sort_values(by='Ones',)

# %%
Complaint_Counts
# Out:
#              Complaint Type     Ones
# 4          Blocked Driveway  77044.0
# 12          Illegal Parking  75361.0
# 16  Noise - Street/Sidewalk  48612.0
# 13       Noise - Commercial  35577.0
# 5          Derelict Vehicle  17718.0
# 17          Noise - Vehicle  17083.0
# 1              Animal Abuse   7778.0
# 21                  Traffic   4498.0
# 10      Homeless Encampment   4416.0
# 15             Noise - Park   4042.0

# %%
plt.figure(figsize=(18,8))
sns.barplot(data=Complaint_Counts, x='Complaint Type', y='Ones')
plt.tight_layout()

# %%
Address_Count=data.groupby('City').sum()['Ones'].reset_index().sort_values(by='Ones',ascending=False).head(10)

# %%
plt.figure(figsize=(18,8))
sns.barplot(data=Address_Count,y='Ones',x='City')
plt.tight_layout()

# %%
data.head()
# Out:
#    Unique Key        Created Date         Closed Date Agency  \
# 0    32310363 2015-12-31 23:59:45 2016-01-01 00:55:00   NYPD
# 1    32309934 2015-12-31 23:59:44 2016-01-01 01:26:00   NYPD
# 2    32309159 2015-12-31 23:59:29 2016-01-01 04:51:00   NYPD
# 3    32305098 2015-12-31 23:57:46 2016-01-01 07:43:00   NYPD
# 4    32306529 2015-12-31 23:56:58 2016-01-01 03:24:00   NYPD
#
#                        Agency Name           Complaint Type  \
# 0  New York City Police Department  Noise - Street/Sidewalk
# 1  New York City Police Department         Blocked Driveway
# 2  New York City Police Department         Blocked Driveway
# 3  New York City Police Department          Illegal Parking
# 4  New York City Police Department          Illegal Parking
#
#                      Descriptor    Location Type  Incident Zip  \
# 0              Loud Music/Party  Street/Sidewalk       10034.0
# 1                     No Access  Street/Sidewalk       11105.0
# ...
